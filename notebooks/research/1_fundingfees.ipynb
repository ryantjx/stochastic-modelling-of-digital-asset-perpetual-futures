# %% [markdown]
# # 1 Understanding Funding Fees
#
# On most platforms, Funding Fees are paid hourly based on the difference between the future and spot price. For more details about funding rates, please refer to the [Hyperliquid Docs](https://hyperliquid.gitbook.io/hyperliquid-docs/trading/funding) and [Coinbase Docs](https://help.coinbase.com/en/international-exchange/funding/how-is-the-funding-rate-determined).
#
# For the sake of simplicity, we shall focus on using data extracted from Hyperliquid (aggregation) and Binance (individual exchange) to attempt to understand the behaviour of funding rates, and how much we should expect to be paying.
#
# There should be an analytical solution for this...
#
# Some of the questions I want to answer
# 1. What is the average funding rate historically?
# 2. What sort of distribution is the funding rates? (assuming Funding Rate is mean reverting)
# 3. What is the expected amount that I can pay for a certain duration for Bitcoin?
#    1. monte carlo simulation? -> mean of 10.95%
#    2. hourly data -> how much I can expect to pay for a portfolio (in notional value?)
#    3. For 1 / 2 / 3 month, how much funding should I expect to pay? What is the range of values that I will expect to pay?
# 4. How is the different for the different tokens?
#
# ## Assumptions
# 1. Funding Rates are IID
# 2. Funding Rates across platforms are non-correlated.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import requests
import json

from datetime import datetime, timedelta
import pytz

import scipy.stats as scipy_stats

# %% [markdown]
# # Coinbase
#
# https://github.com/coinbase/coinbase-advanced-py/
#
# Endpoint: [Get historical funding rates](https://docs.cdp.coinbase.com/intx/reference/getInstrumentFunding/)
#
# PROBLEM: NEED TO FIGURE OUT HOW TO GET >100 data points

# %%
def get_coinbase_funding(instrument):
    url = f"""https://api.international.coinbase.com/api/v1/instruments/{instrument}/funding"""
    headers = {
        'Content-Type': 'application/json',
        'Accept': 'application/json'
    }
    params = {
        'result_limit': 100,
    }
    response = requests.get(url, headers=headers, params=params)
    return response.json()

data = get_coinbase_funding('BTC-PERP')
data
# Out:
# {'pagination': {'result_limit': 100, 'result_offset': 0},
#  'results': [{'instrument_id': '149264167780483072',
#    'funding_rate': '0.000003',
#    'mark_price': '102156.1',
#    'event_time': '2025-02-01T08:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000003',
#    'mark_price': '102396',
#    'event_time': '2025-02-01T07:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000003',
#    'mark_price': '102485.6',
#    'event_time': '2025-02-01T06:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000002',
#    'mark_price': '102300.9',
#    'event_time': '2025-02-01T05:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000002',
#    'mark_price': '102229.5',
#    'event_time': '2025-02-01T04:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000002',
#    'mark_price': '102437.2',
#    'event_time': '2025-02-01T03:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000003',
#    'mark_price': '102545.9',
#    'event_time': '2025-02-01T02:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '102460.2',
#    'event_time': '2025-02-01T01:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '102415.9',
#    'event_time': '2025-02-01T00:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000008',
#    'mark_price': '102250.2',
#    'event_time': '2025-01-31T23:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000011',
#    'mark_price': '102128',
#    'event_time': '2025-01-31T22:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000014',
#    'mark_price': '101646.1',
#    'event_time': '2025-01-31T21:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000014',
#    'mark_price': '102287.1',
#    'event_time': '2025-01-31T20:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000008',
#    'mark_price': '102634.8',
#    'event_time': '2025-01-31T19:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '104599.3',
#    'event_time': '2025-01-31T18:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '105104.1',
#    'event_time': '2025-01-31T17:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '105487.9',
#    'event_time': '2025-01-31T16:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000008',
#    'mark_price': '104474.3',
#    'event_time': '2025-01-31T15:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000008',
#    'mark_price': '104683.3',
#    'event_time': '2025-01-31T14:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '104722.8',
#    'event_time': '2025-01-31T13:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '104746.1',
#    'event_time': '2025-01-31T12:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '104292.3',
#    'event_time': '2025-01-31T11:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '104267.2',
#    'event_time': '2025-01-31T10:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '104029.9',
#    'event_time': '2025-01-31T09:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000008',
#    'mark_price': '104204.6',
#    'event_time': '2025-01-31T08:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000008',
#    'mark_price': '104525.1',
#    'event_time': '2025-01-31T07:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '104322.1',
#    'event_time': '2025-01-31T06:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '104019.9',
#    'event_time': '2025-01-31T05:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '104344.1',
#    'event_time': '2025-01-31T04:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '104359.2',
#    'event_time': '2025-01-31T03:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '104748.3',
#    'event_time': '2025-01-31T02:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '104917.5',
#    'event_time': '2025-01-31T01:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000004',
#    'mark_price': '104744',
#    'event_time': '2025-01-31T00:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000003',
#    'mark_price': '105107.5',
#    'event_time': '2025-01-30T23:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000003',
#    'mark_price': '105064.8',
#    'event_time': '2025-01-30T22:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000004',
#    'mark_price': '104928.4',
#    'event_time': '2025-01-30T21:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000004',
#    'mark_price': '105735.9',
#    'event_time': '2025-01-30T20:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '105605.2',
#    'event_time': '2025-01-30T19:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '105316',
#    'event_time': '2025-01-30T18:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.00001',
#    'mark_price': '105721.8',
#    'event_time': '2025-01-30T17:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000013',
#    'mark_price': '105602.5',
#    'event_time': '2025-01-30T16:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000015',
#    'mark_price': '105951.9',
#    'event_time': '2025-01-30T15:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000015',
#    'mark_price': '104909.1',
#    'event_time': '2025-01-30T14:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000013',
#    'mark_price': '105040',
#    'event_time': '2025-01-30T13:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000013',
#    'mark_price': '105330',
#    'event_time': '2025-01-30T12:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000013',
#    'mark_price': '105363.9',
#    'event_time': '2025-01-30T11:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000013',
#    'mark_price': '105436.3',
#    'event_time': '2025-01-30T10:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000012',
#    'mark_price': '105082.2',
#    'event_time': '2025-01-30T09:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000012',
#    'mark_price': '105161.9',
#    'event_time': '2025-01-30T08:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000013',
#    'mark_price': '105220.4',
#    'event_time': '2025-01-30T07:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000015',
#    'mark_price': '105411.9',
#    'event_time': '2025-01-30T06:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000018',
#    'mark_price': '105518',
#    'event_time': '2025-01-30T05:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000015',
#    'mark_price': '105222.1',
#    'event_time': '2025-01-30T04:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000015',
#    'mark_price': '104702',
#    'event_time': '2025-01-30T03:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000015',
#    'mark_price': '104295.8',
#    'event_time': '2025-01-30T02:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000014',
#    'mark_price': '104062',
#    'event_time': '2025-01-30T01:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000014',
#    'mark_price': '103782',
#    'event_time': '2025-01-30T00:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000013',
#    'mark_price': '103521.5',
#    'event_time': '2025-01-29T23:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.00001',
#    'mark_price': '103781.5',
#    'event_time': '2025-01-29T22:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '104233.7',
#    'event_time': '2025-01-29T21:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000003',
#    'mark_price': '103582.1',
#    'event_time': '2025-01-29T20:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000004',
#    'mark_price': '102838',
#    'event_time': '2025-01-29T19:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '102401.8',
#    'event_time': '2025-01-29T18:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '102086',
#    'event_time': '2025-01-29T17:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '101960.1',
#    'event_time': '2025-01-29T16:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '102007.8',
#    'event_time': '2025-01-29T15:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '101812.1',
#    'event_time': '2025-01-29T14:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '102216',
#    'event_time': '2025-01-29T13:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '102600.6',
#    'event_time': '2025-01-29T12:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '102517.9',
#    'event_time': '2025-01-29T11:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '102305.9',
#    'event_time': '2025-01-29T10:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '102713.9',
#    'event_time': '2025-01-29T09:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '102732.1',
#    'event_time': '2025-01-29T08:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '102790',
#    'event_time': '2025-01-29T07:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '102245.3',
#    'event_time': '2025-01-29T06:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '101974.4',
#    'event_time': '2025-01-29T05:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '102014.3',
#    'event_time': '2025-01-29T04:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '101762.1',
#    'event_time': '2025-01-29T03:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '101801.1',
#    'event_time': '2025-01-29T02:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '101650',
#    'event_time': '2025-01-29T01:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '101284.1',
#    'event_time': '2025-01-29T00:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '101210.5',
#    'event_time': '2025-01-28T23:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '100294.3',
#    'event_time': '2025-01-28T22:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000006',
#    'mark_price': '101244.1',
#    'event_time': '2025-01-28T21:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '102406.1',
#    'event_time': '2025-01-28T20:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '102194',
#    'event_time': '2025-01-28T19:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '102572.1',
#    'event_time': '2025-01-28T18:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '102259.1',
#    'event_time': '2025-01-28T17:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000004',
#    'mark_price': '102786',
#    'event_time': '2025-01-28T16:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000005',
#    'mark_price': '102638',
#    'event_time': '2025-01-28T15:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '102595.9',
#    'event_time': '2025-01-28T14:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000008',
#    'mark_price': '102609.9',
#    'event_time': '2025-01-28T13:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000008',
#    'mark_price': '102768',
#    'event_time': '2025-01-28T12:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000007',
#    'mark_price': '102756.2',
#    'event_time': '2025-01-28T11:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000004',
#    'mark_price': '102959.4',
#    'event_time': '2025-01-28T10:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '0.000001',
#    'mark_price': '102859.9',
#    'event_time': '2025-01-28T09:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '-0.000002',
#    'mark_price': '102800',
#    'event_time': '2025-01-28T08:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '-0.000003',
#    'mark_price': '102731.8',
#    'event_time': '2025-01-28T07:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '-0.000003',
#    'mark_price': '103006.1',
#    'event_time': '2025-01-28T06:00:00Z'},
#   {'instrument_id': '149264167780483072',
#    'funding_rate': '-0.000002',
#    'mark_price': '102907.9',
#    'event_time': '2025-01-28T05:00:00Z'}]}

# %%
df = pd.DataFrame(data['results'])
df['funding_rate'] = df['funding_rate'].astype(float)
df['funding_annualized'] = df['funding_rate'].apply(lambda x : x * 24 * 365 * 100)
df['event_time'] = pd.to_datetime(df['event_time'])
df
# Out:
#          instrument_id  funding_rate mark_price                event_time  \
# 0   149264167780483072      0.000003   102156.1 2025-02-01 08:00:00+00:00
# 1   149264167780483072      0.000003     102396 2025-02-01 07:00:00+00:00
# 2   149264167780483072      0.000003   102485.6 2025-02-01 06:00:00+00:00
# 3   149264167780483072      0.000002   102300.9 2025-02-01 05:00:00+00:00
# 4   149264167780483072      0.000002   102229.5 2025-02-01 04:00:00+00:00
# ..                 ...           ...        ...                       ...
# 95  149264167780483072      0.000001   102859.9 2025-01-28 09:00:00+00:00
# 96  149264167780483072     -0.000002     102800 2025-01-28 08:00:00+00:00
# 97  149264167780483072     -0.000003   102731.8 2025-01-28 07:00:00+00:00
# 98  149264167780483072     -0.000003   103006.1 2025-01-28 06:00:00+00:00
# 99  149264167780483072     -0.000002   102907.9 2025-01-28 05:00:00+00:00
#
#     funding_annualized
# 0                2.628
# 1                2.628
# 2                2.628
# 3                1.752
# 4                1.752
# ..                 ...
# 95               0.876
# 96              -1.752
# 97              -2.628
# 98              -2.628
# 99              -1.752
#
# [100 rows x 5 columns]

# %%
def plot_data(df, x_col, y_col, plot_type='scatter', title=None, xlabel=None, ylabel=None):   
   plt.figure(figsize=(20,6))
   
   if plot_type == 'scatter':
       plt.scatter(df[x_col], df[y_col])
   elif plot_type == 'line': 
       plt.plot(df[x_col], df[y_col])
       
   plt.title(title or f'{y_col} vs {x_col}')
   plt.axhline(0, color='black', lw=1)
   plt.xlabel(xlabel or x_col)
   plt.ylabel(ylabel or y_col)
   plt.grid(True)
   plt.show()

plot_data (df, 'event_time', 'funding_annualized', plot_type='line', title='Funding Rate vs Time', xlabel='Time', ylabel='Funding Rate')

# %% [markdown]
# # Hyperliquid
#
# Endpoint: [Retrieve historical funding rates](https://hyperliquid.gitbook.io/hyperliquid-docs/for-developers/api/info-endpoint/perpetuals#retrieve-historical-funding-rates)

# %%
url = f"""https://api.hyperliquid.xyz/info"""
headers = {
    "Content-Type" : "application/json",
}
payload = {
    "type": "fundingHistory",
    "coin": "ETH",
    "startTime": 1838363554000,
}
response = requests.post(url, headers=headers, data=json.dumps(payload))
response.json()
# Out:
# []

# %%
def get_hyperliquid_funding(instrument, startTime, endTime = int(datetime.now(tz=pytz.UTC).timestamp() * 1000)):
    url = f"""https://api.hyperliquid.xyz/info"""
    headers = {
        "Content-Type" : "application/json",
    }
    all_data = []

    query_time = startTime
    print(f"""Hyperliquid : Querying funding data for {instrument} from {datetime.fromtimestamp(startTime/1000).strftime("%Y-%m-%d %H:%M:%S")} to {datetime.fromtimestamp(endTime/1000).strftime("%Y-%m-%d %H:%M:%S")}""")
    while query_time < endTime:
        payload = {
            "type": "fundingHistory",
            "coin": instrument,
            "startTime": query_time,
            "endTime": endTime
        }
        response = requests.post(url, headers=headers, json=payload)
        # return response.text
        if response.status_code != 200:
            raise Exception(f"Error {response.status_code} : {response.text}")
        data = response.json()
        if len(data) == 0:
            break
        all_data.extend(data)

        # update query_time
        query_time = data[-1]['time'] + 1

    return all_data
startTime = int(datetime(2023, 7, 1, 0, 0, 0, tzinfo=pytz.UTC).timestamp() * 1000)
data = get_hyperliquid_funding(instrument='BTC', startTime=startTime)
data
# Out:
# Hyperliquid : Querying funding data for BTC from 2023-07-01 08:00:00 to 2025-02-01 16:17:37
# [{'coin': 'BTC',
#   'fundingRate': '0.00005087',
#   'premium': '0.00040698',
#   'time': 1688169600189},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005791',
#   'premium': '0.00046326',
#   'time': 1688173200008},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004873',
#   'premium': '0.00038988',
#   'time': 1688176800067},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004512',
#   'premium': '0.00036094',
#   'time': 1688180400024},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000399',
#   'premium': '0.00031921',
#   'time': 1688184000166},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005543',
#   'premium': '0.00044343',
#   'time': 1688187600117},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004059',
#   'premium': '0.0003247',
#   'time': 1688191200051},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003471',
#   'premium': '0.00027766',
#   'time': 1688194800137},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003934',
#   'premium': '0.00031475',
#   'time': 1688198400278},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003513',
#   'premium': '0.00028105',
#   'time': 1688202000155},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003975',
#   'premium': '0.00031798',
#   'time': 1688205600136},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004126',
#   'premium': '0.00033008',
#   'time': 1688209200069},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004818',
#   'premium': '0.00038544',
#   'time': 1688212800227},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005119',
#   'premium': '0.00040955',
#   'time': 1688216400071},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005241',
#   'premium': '0.00041924',
#   'time': 1688220000212},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005582',
#   'premium': '0.00044657',
#   'time': 1688223600085},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006464',
#   'premium': '0.00051711',
#   'time': 1688227200066},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006222',
#   'premium': '0.00049774',
#   'time': 1688230800166},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004791',
#   'premium': '0.00038331',
#   'time': 1688234400213},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004759',
#   'premium': '0.00038075',
#   'time': 1688238000405},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004537',
#   'premium': '0.00036292',
#   'time': 1688241600141},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004218',
#   'premium': '0.00033745',
#   'time': 1688245200081},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003908',
#   'premium': '0.00031268',
#   'time': 1688248800159},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004378',
#   'premium': '0.00035024',
#   'time': 1688252400002},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004545',
#   'premium': '0.0003636',
#   'time': 1688256000133},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006267',
#   'premium': '0.0005014',
#   'time': 1688259600093},
#  {'coin': 'BTC',
#   'fundingRate': '0.000062',
#   'premium': '0.00049602',
#   'time': 1688263200048},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007977',
#   'premium': '0.00063815',
#   'time': 1688266800285},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006717',
#   'premium': '0.00053734',
#   'time': 1688270400093},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007345',
#   'premium': '0.0005876',
#   'time': 1688274000017},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007116',
#   'premium': '0.00056929',
#   'time': 1688277600176},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007252',
#   'premium': '0.00058017',
#   'time': 1688281200221},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006399',
#   'premium': '0.00051189',
#   'time': 1688284800072},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006478',
#   'premium': '0.00051821',
#   'time': 1688288400064},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000613',
#   'premium': '0.00049041',
#   'time': 1688292000084},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007026',
#   'premium': '0.00056207',
#   'time': 1688295600093},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007155',
#   'premium': '0.00057241',
#   'time': 1688299200145},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006019',
#   'premium': '0.00048152',
#   'time': 1688302800005},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006475',
#   'premium': '0.00051796',
#   'time': 1688306400029},
#  {'coin': 'BTC',
#   'fundingRate': '0.00008807',
#   'premium': '0.00070459',
#   'time': 1688310000117},
#  {'coin': 'BTC',
#   'fundingRate': '0.00009817',
#   'premium': '0.00078532',
#   'time': 1688313600370},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007918',
#   'premium': '0.00063343',
#   'time': 1688317200005},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000587',
#   'premium': '0.00046958',
#   'time': 1688320800166},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007148',
#   'premium': '0.00057186',
#   'time': 1688324400235},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004734',
#   'premium': '0.00037872',
#   'time': 1688331600180},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005316',
#   'premium': '0.00042531',
#   'time': 1688335200112},
#  {'coin': 'BTC',
#   'fundingRate': '0.00009163',
#   'premium': '0.00073305',
#   'time': 1688338800201},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007784',
#   'premium': '0.0006227',
#   'time': 1688342400162},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005269',
#   'premium': '0.00042155',
#   'time': 1688346000081},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005582',
#   'premium': '0.00044656',
#   'time': 1688349600278},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005295',
#   'premium': '0.00042363',
#   'time': 1688353200194},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004631',
#   'premium': '0.00037049',
#   'time': 1688356800066},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005471',
#   'premium': '0.00043769',
#   'time': 1688360400066},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004946',
#   'premium': '0.00039565',
#   'time': 1688364000158},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000645',
#   'premium': '0.00051598',
#   'time': 1688367600110},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007085',
#   'premium': '0.00056678',
#   'time': 1688371200172},
#  {'coin': 'BTC',
#   'fundingRate': '0.00011978',
#   'premium': '0.00095821',
#   'time': 1688374800195},
#  {'coin': 'BTC',
#   'fundingRate': '0.00009795',
#   'premium': '0.00078363',
#   'time': 1688378400017},
#  {'coin': 'BTC',
#   'fundingRate': '0.00010897',
#   'premium': '0.00087176',
#   'time': 1688382000022},
#  {'coin': 'BTC',
#   'fundingRate': '0.00012791',
#   'premium': '0.00102324',
#   'time': 1688385600054},
#  {'coin': 'BTC',
#   'fundingRate': '0.00012522',
#   'premium': '0.00100178',
#   'time': 1688389200041},
#  {'coin': 'BTC',
#   'fundingRate': '0.00011015',
#   'premium': '0.00088124',
#   'time': 1688392800379},
#  {'coin': 'BTC',
#   'fundingRate': '0.00010437',
#   'premium': '0.00083493',
#   'time': 1688396400144},
#  {'coin': 'BTC',
#   'fundingRate': '0.00010369',
#   'premium': '0.00082953',
#   'time': 1688400000092},
#  {'coin': 'BTC',
#   'fundingRate': '0.00009548',
#   'premium': '0.00076383',
#   'time': 1688403600184},
#  {'coin': 'BTC',
#   'fundingRate': '0.00008187',
#   'premium': '0.00065493',
#   'time': 1688407200064},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000869',
#   'premium': '0.00069519',
#   'time': 1688410800163},
#  {'coin': 'BTC',
#   'fundingRate': '0.00011613',
#   'premium': '0.00092907',
#   'time': 1688414400113},
#  {'coin': 'BTC',
#   'fundingRate': '0.00009081',
#   'premium': '0.00072648',
#   'time': 1688418000502},
#  {'coin': 'BTC',
#   'fundingRate': '0.00008989',
#   'premium': '0.00071908',
#   'time': 1688421600201},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007303',
#   'premium': '0.00058427',
#   'time': 1688425200188},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005917',
#   'premium': '0.00047334',
#   'time': 1688428800072},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005709',
#   'premium': '0.00045671',
#   'time': 1688432400024},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000696',
#   'premium': '0.0005568',
#   'time': 1688436000154},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005229',
#   'premium': '0.00041832',
#   'time': 1688439600054},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004993',
#   'premium': '0.00039941',
#   'time': 1688443200063},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005712',
#   'premium': '0.00045699',
#   'time': 1688446800103},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005488',
#   'premium': '0.00043901',
#   'time': 1688450400063},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005156',
#   'premium': '0.00041244',
#   'time': 1688454000058},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004182',
#   'premium': '0.00033455',
#   'time': 1688457600029},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004207',
#   'premium': '0.00033656',
#   'time': 1688461200033},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005889',
#   'premium': '0.00047112',
#   'time': 1688464800063},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005612',
#   'premium': '0.00044895',
#   'time': 1688468400017},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004974',
#   'premium': '0.00039795',
#   'time': 1688472000073},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006226',
#   'premium': '0.00049809',
#   'time': 1688475600078},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006363',
#   'premium': '0.00050904',
#   'time': 1688479200074},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006311',
#   'premium': '0.00050488',
#   'time': 1688482800106},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007409',
#   'premium': '0.00059273',
#   'time': 1688486400152},
#  {'coin': 'BTC',
#   'fundingRate': '0.00009079',
#   'premium': '0.00072636',
#   'time': 1688490000259},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007397',
#   'premium': '0.00059174',
#   'time': 1688493600181},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006647',
#   'premium': '0.00053173',
#   'time': 1688497200336},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004297',
#   'premium': '0.0003438',
#   'time': 1688500800055},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002189',
#   'premium': '0.00017512',
#   'time': 1688504400071},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001625',
#   'premium': '0.00013',
#   'time': 1688508000069},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002609',
#   'premium': '0.0002087',
#   'time': 1688511600097},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002707',
#   'premium': '0.00021656',
#   'time': 1688515200201},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002323',
#   'premium': '0.00018583',
#   'time': 1688518800213},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001603',
#   'premium': '0.00012825',
#   'time': 1688522400203},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001788',
#   'premium': '0.00014303',
#   'time': 1688526000151},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001245',
#   'premium': '0.00009957',
#   'time': 1688529600020},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001022',
#   'premium': '0.00008174',
#   'time': 1688533200188},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000221',
#   'premium': '0.00001768',
#   'time': 1688536800868},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000676',
#   'premium': '0.00005407',
#   'time': 1688540400320},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000121',
#   'premium': '0.00009678',
#   'time': 1688544000422},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003701',
#   'premium': '0.00029606',
#   'time': 1688547600004},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000256',
#   'premium': '0.00020477',
#   'time': 1688551200058},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003883',
#   'premium': '0.00031064',
#   'time': 1688554800079},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003261',
#   'premium': '0.00026085',
#   'time': 1688558400202},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003776',
#   'premium': '0.00030207',
#   'time': 1688562000002},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005267',
#   'premium': '0.00042135',
#   'time': 1688565600120},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003418',
#   'premium': '0.00027345',
#   'time': 1688569200184},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002783',
#   'premium': '0.00022262',
#   'time': 1688572800124},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001846',
#   'premium': '0.00014769',
#   'time': 1688576400145},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002521',
#   'premium': '0.00020165',
#   'time': 1688580000322},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002306',
#   'premium': '0.00018446',
#   'time': 1688583600137},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002003',
#   'premium': '0.00016022',
#   'time': 1688587200189},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000232',
#   'premium': '0.00018559',
#   'time': 1688590800065},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001883',
#   'premium': '0.00015063',
#   'time': 1688594400063},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002764',
#   'premium': '0.00022114',
#   'time': 1688598000171},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002295',
#   'premium': '0.00018357',
#   'time': 1688601600104},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002498',
#   'premium': '0.00019985',
#   'time': 1688605200174},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002064',
#   'premium': '0.00016512',
#   'time': 1688608800187},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002538',
#   'premium': '0.00020304',
#   'time': 1688612400098},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001047',
#   'premium': '0.00008373',
#   'time': 1688616000175},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000085',
#   'premium': '0.00000676',
#   'time': 1688619600185},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001638',
#   'premium': '0.00013101',
#   'time': 1688623200217},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002162',
#   'premium': '0.00017298',
#   'time': 1688626800087},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000457',
#   'premium': '0.00003658',
#   'time': 1688630400133},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004168',
#   'premium': '0.0003334',
#   'time': 1688634000290},
#  {'coin': 'BTC',
#   'fundingRate': '0.00008723',
#   'premium': '0.00069783',
#   'time': 1688637600088},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004787',
#   'premium': '0.00038294',
#   'time': 1688641200192},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003351',
#   'premium': '0.00026809',
#   'time': 1688644800006},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002892',
#   'premium': '0.00023134',
#   'time': 1688648400001},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001401',
#   'premium': '0.00011208',
#   'time': 1688652000020},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007379',
#   'premium': '0.00059034',
#   'time': 1688655600083},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005766',
#   'premium': '0.00046127',
#   'time': 1688659200165},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000646',
#   'premium': '0.00051683',
#   'time': 1688662800170},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005603',
#   'premium': '0.00044826',
#   'time': 1688666400236},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000541',
#   'premium': '0.0004328',
#   'time': 1688670000245},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005819',
#   'premium': '0.00046551',
#   'time': 1688673600126},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000485',
#   'premium': '0.00038802',
#   'time': 1688677200065},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005952',
#   'premium': '0.00047614',
#   'time': 1688680800091},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004162',
#   'premium': '0.00033294',
#   'time': 1688684400088},
#  {'coin': 'BTC',
#   'fundingRate': '0.00009038',
#   'premium': '0.00072308',
#   'time': 1688688000296},
#  {'coin': 'BTC',
#   'fundingRate': '0.00011438',
#   'premium': '0.00091507',
#   'time': 1688691600219},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006548',
#   'premium': '0.00052385',
#   'time': 1688695200408},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005629',
#   'premium': '0.00045029',
#   'time': 1688698800351},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006976',
#   'premium': '0.0005581',
#   'time': 1688702400092},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007092',
#   'premium': '0.00056735',
#   'time': 1688706000055},
#  {'coin': 'BTC',
#   'fundingRate': '0.000099',
#   'premium': '0.000792',
#   'time': 1688709600190},
#  {'coin': 'BTC',
#   'fundingRate': '0.00009628',
#   'premium': '0.00077023',
#   'time': 1688713200072},
#  {'coin': 'BTC',
#   'fundingRate': '0.00009071',
#   'premium': '0.00072565',
#   'time': 1688716800039},
#  {'coin': 'BTC',
#   'fundingRate': '0.00008597',
#   'premium': '0.00068774',
#   'time': 1688720400104},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006858',
#   'premium': '0.00054863',
#   'time': 1688724000175},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007083',
#   'premium': '0.00056666',
#   'time': 1688727600276},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007484',
#   'premium': '0.00059875',
#   'time': 1688731200135},
#  {'coin': 'BTC',
#   'fundingRate': '0.00011676',
#   'premium': '0.00093404',
#   'time': 1688734800197},
#  {'coin': 'BTC',
#   'fundingRate': '0.00009903',
#   'premium': '0.0007922',
#   'time': 1688738400149},
#  {'coin': 'BTC',
#   'fundingRate': '0.00007871',
#   'premium': '0.00062969',
#   'time': 1688742000198},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005543',
#   'premium': '0.00044343',
#   'time': 1688745600167},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000464',
#   'premium': '0.00037117',
#   'time': 1688749200044},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000815',
#   'premium': '0.00006521',
#   'time': 1688752800064},
#  {'coin': 'BTC',
#   'fundingRate': '0.00006885',
#   'premium': '0.00055079',
#   'time': 1688756400064},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005736',
#   'premium': '0.00045889',
#   'time': 1688760000026},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005862',
#   'premium': '0.00046895',
#   'time': 1688763600171},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000598',
#   'premium': '0.00047839',
#   'time': 1688767200352},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004966',
#   'premium': '0.00039732',
#   'time': 1688770800007},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003642',
#   'premium': '0.00029137',
#   'time': 1688774400142},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003992',
#   'premium': '0.00031933',
#   'time': 1688778000183},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004198',
#   'premium': '0.00033586',
#   'time': 1688781600018},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005725',
#   'premium': '0.00045799',
#   'time': 1688785200000},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000458',
#   'premium': '0.00036638',
#   'time': 1688788800187},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000535',
#   'premium': '0.00042797',
#   'time': 1688792400154},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003556',
#   'premium': '0.00028451',
#   'time': 1688796000046},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002565',
#   'premium': '0.00020523',
#   'time': 1688799600053},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001755',
#   'premium': '0.0001404',
#   'time': 1688803200115},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003611',
#   'premium': '0.00028885',
#   'time': 1688806800382},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003012',
#   'premium': '0.00024097',
#   'time': 1688810400087},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000261',
#   'premium': '0.00020879',
#   'time': 1688814000175},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002791',
#   'premium': '0.00022325',
#   'time': 1688817600008},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002098',
#   'premium': '0.00016783',
#   'time': 1688821200145},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001423',
#   'premium': '0.00011381',
#   'time': 1688824800117},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001291',
#   'premium': '0.00010329',
#   'time': 1688828400086},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002271',
#   'premium': '0.00018165',
#   'time': 1688832000293},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000326',
#   'premium': '0.00026078',
#   'time': 1688835600147},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002586',
#   'premium': '0.00020685',
#   'time': 1688839200213},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002423',
#   'premium': '0.00019385',
#   'time': 1688842800182},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004277',
#   'premium': '0.00034216',
#   'time': 1688846400202},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003401',
#   'premium': '0.00027205',
#   'time': 1688850000194},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001878',
#   'premium': '0.00015028',
#   'time': 1688853600098},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002845',
#   'premium': '0.00022757',
#   'time': 1688857200131},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003441',
#   'premium': '0.00027528',
#   'time': 1688860800175},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003908',
#   'premium': '0.00031263',
#   'time': 1688864400029},
#  {'coin': 'BTC',
#   'fundingRate': '0.0000421',
#   'premium': '0.0003368',
#   'time': 1688868000208},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003091',
#   'premium': '0.00024725',
#   'time': 1688871600325},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002862',
#   'premium': '0.00022897',
#   'time': 1688875200132},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002332',
#   'premium': '0.00018653',
#   'time': 1688878800284},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001844',
#   'premium': '0.00014752',
#   'time': 1688882400181},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002443',
#   'premium': '0.00019546',
#   'time': 1688886000311},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002726',
#   'premium': '0.00021808',
#   'time': 1688889600428},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001678',
#   'premium': '0.00013427',
#   'time': 1688893200075},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002236',
#   'premium': '0.00017891',
#   'time': 1688896800181},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001488',
#   'premium': '0.00011905',
#   'time': 1688900400071},
#  {'coin': 'BTC',
#   'fundingRate': '0.00001819',
#   'premium': '0.00014551',
#   'time': 1688904000009},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002446',
#   'premium': '0.00019568',
#   'time': 1688907600050},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002617',
#   'premium': '0.00020934',
#   'time': 1688911200004},
#  {'coin': 'BTC',
#   'fundingRate': '0.00005223',
#   'premium': '0.00041783',
#   'time': 1688914800035},
#  {'coin': 'BTC',
#   'fundingRate': '0.00004749',
#   'premium': '0.00037996',
#   'time': 1688918400002},
#  {'coin': 'BTC',
#   'fundingRate': '0.00003348',
#   'premium': '0.00026785',
#   'time': 1688922000143},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002086',
#   'premium': '0.00016688',
#   'time': 1688925600102},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002452',
#   'premium': '0.00019617',
#   'time': 1688929200072},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002364',
#   'premium': '0.00018914',
#   'time': 1688932800026},
#  {'coin': 'BTC',
#   'fundingRate': '0.00002105',
#   'premium': '0.00016841',
#   'time': 1688936400109},
#  {'coin': 'BTC',
#   'fundingRate': '0.00

#  {'coin': 'BTC',
#   'fundingRate': '-0.00001709',
#   'premium': '-0.00043669',
#   'time': 1691636400133},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00001426',
#   'premium': '-0.00041408',
#   'time': 1691640000007},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000946',
#   'premium': '-0.00037568',
#   'time': 1691643600038},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000204',
#   'premium': '-0.00028366',
#   'time': 1691647200061},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000398',
#   'premium': '-0.00033183',
#   'time': 1691650800093},
#  {'coin': 'BTC',
#   'fundingRate': '-0.0000033',
#   'premium': '-0.00032643',
#   'time': 1691654400145},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000318',
#   'premium': '-0.00032541',
#   'time': 1691658000141},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000266',
#   'premium': '-0.00027869',
#   'time': 1691661600173},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000099',
#   'premium': '-0.00030793',
#   'time': 1691665200094},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000219',
#   'premium': '-0.0003175',
#   'time': 1691668800082},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000944',
#   'premium': '-0.00037549',
#   'time': 1691672400096},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000887',
#   'premium': '-0.00037093',
#   'time': 1691676000185},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00001319',
#   'premium': '-0.0004055',
#   'time': 1691679600390},
#  {'coin': 'BTC',
#   'fundingRate': '-0.0000186',
#   'premium': '-0.00044877',
#   'time': 1691683200106},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00001005',
#   'premium': '-0.0003804',
#   'time': 1691686800096},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000496',
#   'premium': '-0.00033972',
#   'time': 1691690400213},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000253',
#   'premium': '-0.00032021',
#   'time': 1691694000085},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000503',
#   'premium': '-0.00025973',
#   'time': 1691697600071},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000518',
#   'premium': '-0.00025854',
#   'time': 1691701200072},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000835',
#   'premium': '-0.00023322',
#   'time': 1691704800098},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000704',
#   'premium': '-0.0003563',
#   'time': 1691708400070},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00001336',
#   'premium': '-0.0004069',
#   'time': 1691712000143},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000079',
#   'premium': '-0.00030633',
#   'time': 1691715600151},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000568',
#   'premium': '-0.00034546',
#   'time': 1691719200080},
#  {'coin': 'BTC',
#   'fundingRate': '-0.0000034',
#   'premium': '-0.00032722',
#   'time': 1691722800022},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000754',
#   'premium': '-0.00023965',
#   'time': 1691726400178},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000167',
#   'premium': '-0.00031333',
#   'time': 1691730000053},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000728',
#   'premium': '-0.00024179',
#   'time': 1691733600153},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000423',
#   'premium': '-0.00033382',
#   'time': 1691737200084},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000006',
#   'premium': '-0.00029956',
#   'time': 1691740800039},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000351',
#   'premium': '-0.0002719',
#   'time': 1691744400019},
#  {'coin': 'BTC',
#   'fundingRate': '0.00000173',
#   'premium': '-0.00028619',
#   'time': 1691748000005},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000116',
#   'premium': '-0.00030928',
#   'time': 1691751600044},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000409',
#   'premium': '-0.00033272',
#   'time': 1691755200106},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00001181',
#   'premium': '-0.00039451',
#   'time': 1691758800039},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000916',
#   'premium': '-0.00037327',
#   'time': 1691762400009},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00001588',
#   'premium': '-0.00042705',
#   'time': 1691766000009},
#  {'coin': 'BTC',
#   'fundingRate': '-0.00000585',
#   'premium': '-0.00034682',
#   'time': 1691769600010},
#  ...]

# %%
hl_df = pd.DataFrame(data)
hl_df['datetime'] = pd.to_datetime(hl_df['time'], unit='ms')
hl_df['premium'] = hl_df['premium'].astype(float)
hl_df['fundingRate'] = hl_df['fundingRate'].astype(float)
hl_df['annualizedFundingRate'] = hl_df['fundingRate'].apply(lambda x : x * 24 * 365 * 100)

hl_df
# Out:
#       coin  fundingRate   premium           time                datetime  \
# 0      BTC     0.000051  0.000407  1688169600189 2023-07-01 00:00:00.189
# 1      BTC     0.000058  0.000463  1688173200008 2023-07-01 01:00:00.008
# 2      BTC     0.000049  0.000390  1688176800067 2023-07-01 02:00:00.067
# 3      BTC     0.000045  0.000361  1688180400024 2023-07-01 03:00:00.024
# 4      BTC     0.000040  0.000319  1688184000166 2023-07-01 04:00:00.166
# ...    ...          ...       ...            ...                     ...
# 13945  BTC     0.000013  0.000169  1738382400013 2025-02-01 04:00:00.013
# 13946  BTC     0.000013  0.000114  1738386000078 2025-02-01 05:00:00.078
# 13947  BTC     0.000013  0.000272  1738389600093 2025-02-01 06:00:00.093
# 13948  BTC     0.000013  0.000213  1738393200166 2025-02-01 07:00:00.166
# 13949  BTC     0.000013  0.000132  1738396800046 2025-02-01 08:00:00.046
#
#        annualizedFundingRate
# 0                   44.56212
# 1                   50.72916
# 2                   42.68748
# 3                   39.52512
# 4                   34.95240
# ...                      ...
# 13945               10.95000
# 13946               10.95000
# 13947               10.95000
# 13948               10.95000
# 13949               10.95000
#
# [13950 rows x 6 columns]

# %%
hl_df['fundingRate'].describe()
# Out:
# count    13950.000000
# mean         0.000024
# std          0.000034
# min         -0.000166
# 25%          0.000013
# 50%          0.000013
# 75%          0.000029
# max          0.000598
# Name: fundingRate, dtype: float64

# %%
plot_data (hl_df, 'datetime', 'annualizedFundingRate', plot_type='line', title='Funding Rate vs Time', xlabel='Time', ylabel='Funding Rate')

# %%
plot_data(hl_df, x_col='premium', y_col='annualizedFundingRate', plot_type='scatter', title='Funding Rate vs Premium', xlabel='Premium', ylabel='Funding Rate')

# %% [markdown]
# ## 1 What is the average funding rate historically?

# %%
plot_data (hl_df, 'datetime', 'annualizedFundingRate', plot_type='line', title='Funding Rate vs Time', xlabel='Time', ylabel='Funding Rate')

# %%
plot_data (hl_df[hl_df['datetime'] >= '2025-01-01'], 'datetime', 'annualizedFundingRate', plot_type='line', title='Funding Rate vs Time', xlabel='Time', ylabel='Funding Rate')

# %% [markdown]
# ## 2 What sort of distribution is the funding rates? (assuming Funding Rate is mean reverting)

# %%
def plot_distribution(df, column, bins=30, title=None, xlabel=None):
   """Plot histogram with statistical markers"""
   mean = df[column].mean()
   median = df[column].median()
   std = df[column].std()
   
   plt.figure(figsize=(10,6))
   sns.histplot(data=df[column], bins=bins)
   
   # Add vertical lines for statistics
   plt.axvline(mean, color='red', linestyle='dashed', linewidth=2, label=f'Mean: {mean:.2f}')
   plt.axvline(median, color='green', linestyle='dashed', linewidth=2, label=f'Median: {median:.2f}')
   
   # 1 and 2 std deviations
   plt.axvline(mean + std, color='orange', linestyle=':', linewidth=2, label=f'+1σ: {(mean+std):.2f}')
   plt.axvline(mean - std, color='orange', linestyle=':', linewidth=2, label=f'-1σ: {(mean-std):.2f}')
   plt.axvline(mean + 2*std, color='purple', linestyle=':', linewidth=2, label=f'+2σ: {(mean+2*std):.2f}')
   plt.axvline(mean - 2*std, color='purple', linestyle=':', linewidth=2, label=f'-2σ: {(mean-2*std):.2f}')
   
   plt.title(title or f'Distribution of {column}')
   plt.xlabel(xlabel or column)
   plt.ylabel('Count')
   plt.legend()
   plt.grid(True)
   plt.show()

def analyze_distribution(df, column):
   """Calculate distribution statistics"""
   
   skew = stats.skew(df[column])
   kurt = stats.kurtosis(df[column]) # Fisher kurtosis (normal = 0)
   
   print(f"Skewness: {skew:.3f}")
   print(f"Kurtosis: {kurt:.3f}")

plot_distribution(hl_df, 'annualizedFundingRate', bins=100, title='Distribution of Funding Rate', xlabel='Funding Rate')
analyze_distribution(hl_df, 'annualizedFundingRate')
# Out:
# Skewness: 3.069
# Kurtosis: 20.988

# %% [markdown]
# So we attempt to build a distribution using these values. There are multiple solutions to model the distribution, however, in this context we are not too particular about the model.

# %% [markdown]
# ## 3 What is the expected amount that I can pay for a certain duration for Bitcoin?
#
# Steps
# 1. Fit the distribution of hourly funding rate. Assuming that you are summing the amount at every

# %%
def generate_samples(data, n_steps, dist_type='kde', random_state=None):
    """
    Generate replicable samples using specified distribution
    
    Parameters:
        data: Historical funding rate data
        n_steps: Number of steps to generate
        dist_type: Type of distribution to fit ('kde', 'gamma', 'pearson')
        random_state: Seed for random number generation
    
    Returns:
        Array of generated samples
    """
    # Set random state for reproducibility
    if random_state is not None:
        np.random.seed(random_state)
    
    if dist_type == 'kde':
        # For KDE, we need to set the random state explicitly
        kde = scipy_stats.gaussian_kde(data)
        # Store the original random state
        original_state = np.random.get_state()
        # Set the random state for this specific sampling
        np.random.seed(random_state)
        samples = kde.resample(n_steps)[0]
        # Restore the original random state
        np.random.set_state(original_state)
        return samples
    
    # elif dist_type == 'gamma':
    #     # Fit gamma distribution parameters
    #     shape, loc, scale = stats.gamma.fit(data)
    #     # Generate samples with explicit random_state
    #     return stats.gamma.rvs(shape, loc=loc, scale=scale, 
    #                          size=n_steps, random_state=random_state)
    
    elif dist_type == 'pearson':
        # Fit Pearson Type III distribution parameters
        shape, loc, scale = scipy_stats.pearson3.fit(data)
        # Generate samples with explicit random_state
        return scipy_stats.pearson3.rvs(shape, loc=loc, scale=scale, 
                                size=n_steps, random_state=random_state)
    
    else:
        raise ValueError(f"Unsupported distribution type: {dist_type}")

def simulate_portfolio_adjusted_funding(funding_rates_df, hourly_funding_col, num_simulations=1000, 
                                     duration_hours=2160, dist_type='kde', intial_size = 10000, random_state = 42):
    """
    Run Monte Carlo simulation of funding fees with portfolio size adjustment
    
    Parameters:
        funding_rates_df: DataFrame with fundingRate column
        num_simulations: Number of paths to simulate
        duration_hours: Length of simulation (default 3 months)
        dist_type: Distribution type ('kde', 'gamma', 'pearson')
        initial_portfolio: Starting portfolio size (normalized to 1.0)
    
    Returns:
        portfolio_values: Array of portfolio values over time for each simulation
        funding_rates: Array of simulated funding rates
    """
    rates = funding_rates_df[hourly_funding_col].values
    
    # Initialize arrays
    funding_rates = np.zeros((num_simulations, duration_hours))
    portfolio_values = np.zeros((num_simulations, duration_hours + 1))
    
    # Set initial portfolio value for all simulations
    portfolio_values[:, 0] = intial_size
    
    # Generate paths using specified distribution
    for i in range(num_simulations):
        funding_rates[i] = generate_samples(data=rates, n_steps=duration_hours, dist_type=dist_type, random_state=random_state + i)
        
        # Calculate portfolio value evolution
        for t in range(duration_hours):
            # Current portfolio value affects the funding payment
            funding_payment = portfolio_values[i, t] * (funding_rates[i, t])
            # Update portfolio value after funding payment
            portfolio_values[i, t + 1] = portfolio_values[i, t] - funding_payment
    
    # Create visualization
    plt.figure(figsize=(20, 10))
    time_points = np.arange(duration_hours + 1)
    
    # Plot all individual paths with low opacity
    for path in portfolio_values:
        plt.plot(time_points / 24, path, color='blue', alpha=0.1)
    
    # Plot mean path with higher visibility
    mean_path = np.mean(portfolio_values, axis=0)
    plt.plot(time_points / 24, mean_path, color='red', linewidth=2, 
             label='Mean Portfolio Value')
    
    # Add percentile bands
    # percentiles = np.percentile(portfolio_values, [5, 25, 75, 95], axis=0)
    # plt.fill_between(time_points / 24, percentiles[0], percentiles[1],
    #                  color='gray', alpha=0.3, label='5th-25th Percentile')
    # plt.fill_between(time_points / 24, percentiles[2], percentiles[3],
    #                  color='gray', alpha=0.3, label='75th-95th Percentile')
    
    # Add summary statistics
    final_values = portfolio_values[:, -1]
    total_return = (final_values - intial_size) / intial_size * 100
    
    plt.text(0.02, 0.98, 
             f'Final Portfolio Statistics:\n' +
             f'Mean Value: {np.mean(final_values):.4f}\n' +
             f'Median Value: {np.median(final_values):.4f}\n' +
             f'Std Dev: {np.std(final_values):.4f}\n' +
             f'5th Percentile: {np.percentile(final_values, 5):.4f}\n' +
             f'95th Percentile: {np.percentile(final_values, 95):.4f}\n' +
             f'Mean Return: {np.mean(total_return):.2f}%',
             transform=plt.gca().transAxes,
             bbox=dict(facecolor='white', alpha=0.8),
             verticalalignment='top')
    
    plt.xlabel('Days')
    plt.ylabel(f'Portfolio Value (Starting from {intial_size})')
    plt.title(f'Monte Carlo Simulation of Portfolio Value After Funding Fees\n'
              f'{num_simulations} Paths Over {duration_hours/24:.0f} Days')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    return portfolio_values, funding_rates
    
portfolio_values, funding_rates  = simulate_portfolio_adjusted_funding(hl_df,hourly_funding_col='fundingRate', num_simulations=100, duration_hours=24 * 30 * 12 * 3, dist_type='pearson')

# %% [markdown]
# # 4 What is the expected loss in Funding based for the different tokens?

# %%
tokens = ["BTC", "ETH", "SOL", "XRP"]
startTime = int(datetime(2023, 7, 1, 0, 0, 0, tzinfo=pytz.UTC).timestamp() * 1000)

num_simulations = 50
duration_hours = 24 * 30 * 3
dist_type = 'pearson'
initial_size = 10000

for t in tokens:
    hl_token = get_hyperliquid_funding(instrument=t, startTime=startTime)
    hl_df_token = pd.DataFrame(hl_token)
    hl_df_token['datetime'] = pd.to_datetime(hl_df_token['time'], unit='ms')
    hl_df_token['fundingRate'] = hl_df_token['fundingRate'].astype(float)
    print(hl_df_token[['fundingRate', 'datetime']].describe())
    print(f"""Running Monte Carlo Simulation for : {t}""")
    portfolio_values, funding_rates  = simulate_portfolio_adjusted_funding(
        funding_rates_df = hl_df_token,
        hourly_funding_col='fundingRate', 
        num_simulations=num_simulations, 
        duration_hours=duration_hours, 
        dist_type=dist_type,
        intial_size=initial_size)
# Out:
# Hyperliquid : Querying funding data for BTC from 2023-07-01 08:00:00 to 2025-02-01 16:17:37
#         fundingRate                       datetime
# count  13950.000000                          13950
# mean       0.000024  2024-04-16 16:41:47.256143104
# min       -0.000166     2023-07-01 00:00:00.189000
# 25%        0.000013  2023-11-23 09:15:00.044750080
# 50%        0.000013  2024-04-16 16:30:00.245000192
# 75%        0.000029  2024-09-09 00:45:00.069250048
# max        0.000598     2025-02-01 08:00:00.046000
# std        0.000034                            NaN
# Running Monte Carlo Simulation for : BTC
# Hyperliquid : Querying funding data for ETH from 2023-07-01 08:00:00 to 2025-02-01 16:17:37
#         fundingRate                       datetime
# count  13950.000000                          13950
# mean       0.000024  2024-04-16 16:41:47.256143104
# min       -0.000313     2023-07-01 00:00:00.189000
# 25%        0.000013  2023-11-23 09:15:00.044750080
# 50%        0.000013  2024-04-16 16:30:00.245000192
# 75%        0.000032  2024-09-09 00:45:00.069250048
# max        0.000506     2025-02-01 08:00:00.046000
# std        0.000032                            NaN
# Running Monte Carlo Simulation for : ETH
# Hyperliquid : Querying funding data for SOL from 2023-07-01 08:00:00 to 2025-02-01 16:17:37
#         fundingRate                       datetime
# count  13950.000000                          13950
# mean       0.000028  2024-04-16 16:41:47.256143104
# min       -0.000231     2023-07-01 00:00:00.189000
# 25%        0.000013  2023-11-23 09:15:00.044750080
# 50%        0.000013  2024-04-16 16:30:00.245000192
# 75%        0.000038  2024-09-09 00:45:00.069250048
# max        0.000389     2025-02-01 08:00:00.046000
# std        0.000049                            NaN
# Running Monte Carlo Simulation for : SOL
# Hyperliquid : Querying funding data for XRP from 2023-07-01 08:00:00 to 2025-02-01 16:17:37
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[28], line 10
#       7 initial_size = 10000
#       9 for t in tokens:
# ---> 10     hl_token = get_hyperliquid_funding(instrument=t, startTime=startTime)
#      11     hl_df_token = pd.DataFrame(hl_token)
#      12     hl_df_token['datetime'] = pd.to_datetime(hl_df_token['time'], unit='ms')
#
# Cell In[6], line 20, in get_hyperliquid_funding(instrument, startTime, endTime)
#      18 # return response.text
#      19 if response.status_code != 200:
# ---> 20     raise Exception(f"Error {response.status_code} : {response.text}")
#      21 data = response.json()
#      22 if len(data) == 0:
#
# Exception: Error 429 : null

# %%
hl_token = get_hyperliquid_funding(instrument="XRP", startTime=startTime)
hl_df_token = pd.DataFrame(hl_token)
hl_df_token['datetime'] = pd.to_datetime(hl_df_token['time'], unit='ms')
hl_df_token['fundingRate'] = hl_df_token['fundingRate'].astype(float)
print(hl_df_token[['fundingRate', 'datetime']].describe())
print(f"""Running Monte Carlo Simulation for : {t}""")
portfolio_values, funding_rates  = simulate_portfolio_adjusted_funding(
    funding_rates_df = hl_df_token,
    hourly_funding_col='fundingRate', 
    num_simulations=num_simulations, 
    duration_hours=duration_hours, 
    dist_type=dist_type,
    intial_size=initial_size)
# Out:
# Hyperliquid : Querying funding data for XRP from 2023-07-01 08:00:00 to 2025-02-01 16:17:37
#         fundingRate                       datetime
# count  13950.000000                          13950
# mean       0.000017  2024-04-16 16:41:47.256143104
# min       -0.000257     2023-07-01 00:00:00.189000
# 25%        0.000011  2023-11-23 09:15:00.044750080
# 50%        0.000013  2024-04-16 16:30:00.245000192
# 75%        0.000013  2024-09-09 00:45:00.069250048
# max        0.000318     2025-02-01 08:00:00.046000
# std        0.000036                            NaN
# Running Monte Carlo Simulation for : XRP
